# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sys

print(f"Pandas version: {pd.__version__}")
print(f"Numpy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")
print(f"Python version: {sys.version}")
# Out:
# Pandas version: 2.2.2
# Numpy version: 1.26.4
# Matplotlib version: 3.8.0
# Seaborn version: 0.13.2
# Python version: 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
def read_data(filename):   # Reading the CSV file and returning a DataFrame.
  df=pd.read_csv(filename)
  return df

# %%
filepath="/content/movie_metadata (1).csv"
df=read_data(filepath)
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5029 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
# Renaming Column for better understanding
column_renamed = {
    'movie_title': 'Movie Title',
    'genres': 'Genres',
    'budget': 'Budget',
    'gross': 'Gross',
    'imdb_score': 'IMDB Score',
    'director_name': 'Director',
    'actor_1_name': 'Actor Name 1',
    'actor_2_name': 'Actor Name 2',
    'actor_3_name': 'Actor Name 3',
    'movie_imdb_link': 'Movie IMDB Link',
    'title_year': 'Title Year',
    'language': 'Language',
    'country': 'Country',
    'content_rating': 'Content Rating',
    'color': 'Color',
    'num_voted_users': 'Number of Voted Users',
    'num_user_for_reviews': 'Number of User Reviews',
    'num_critic_for_reviews': 'Number of Critic Reviews',
    'movie_facebook_likes': 'Movie Facebook Likes',
    'director_facebook_likes': 'Director Facebook Likes',
    'actor_1_facebook_likes': 'Actor 1 Facebook Likes',
    'actor_2_facebook_likes': 'Actor 2 Facebook Likes',
    'actor_3_facebook_likes': 'Actor 3 Facebook Likes',
    'cast_total_facebook_likes': 'Cast Total Facebook Likes',
    'duration': 'Duration',
    'facenumber_in_poster': 'Number of Faces in Poster',
    'aspect_ratio': 'Aspect Ratio',
    'plot_keywords': 'Plot Keywords'

}

df = df.rename(columns=column_renamed)


df
# Out:
#       Color           Director  Number of Critic Reviews  Duration  \
# 0     Color      James Cameron                     723.0     178.0
# 1     Color     Gore Verbinski                     302.0     169.0
# 2     Color         Sam Mendes                     602.0     148.0
# 3     Color  Christopher Nolan                     813.0     164.0
# 4       NaN        Doug Walker                       NaN       NaN
# ...     ...                ...                       ...       ...
# 5038  Color        Scott Smith                       1.0      87.0
# 5039  Color                NaN                      43.0      43.0
# 5040  Color   Benjamin Roberds                      13.0      76.0
# 5041  Color        Daniel Hsia                      14.0     100.0
# 5042  Color           Jon Gunn                      43.0      90.0
#
#       Director Facebook Likes  Actor 3 Facebook Likes      Actor Name 2  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       Actor 1 Facebook Likes        Gross                           Genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... Number of User Reviews Language  Country  Content Rating  \
# 0     ...                 3054.0  English      USA           PG-13
# 1     ...                 1238.0  English      USA           PG-13
# 2     ...                  994.0  English       UK           PG-13
# 3     ...                 2701.0  English      USA           PG-13
# 4     ...                    NaN      NaN      NaN             NaN
# ...   ...                    ...      ...      ...             ...
# 5038  ...                    6.0  English   Canada             NaN
# 5039  ...                  359.0  English      USA           TV-14
# 5040  ...                    3.0  English      USA             NaN
# 5041  ...                    9.0  English      USA           PG-13
# 5042  ...                   84.0  English      USA              PG
#
#            Budget  Title Year Actor 2 Facebook Likes IMDB Score  Aspect Ratio  \
# 0     237000000.0      2009.0                  936.0        7.9          1.78
# 1     300000000.0      2007.0                 5000.0        7.1          2.35
# 2     245000000.0      2015.0                  393.0        6.8          2.35
# 3     250000000.0      2012.0                23000.0        8.5          2.35
# 4             NaN         NaN                   12.0        7.1           NaN
# ...           ...         ...                    ...        ...           ...
# 5038          NaN      2013.0                  470.0        7.7           NaN
# 5039          NaN         NaN                  593.0        7.5         16.00
# 5040       1400.0      2013.0                    0.0        6.3           NaN
# 5041          NaN      2012.0                  719.0        6.3          2.35
# 5042       1100.0      2004.0                   23.0        6.6          1.85
#
#      Movie Facebook Likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %%
#Rearranging columns based on local grouping

new_column_arrangement = [
    # Identifiers and Titles
    'Movie Title', 'Title Year', 'Movie IMDB Link',

    # Descriptive Information
    'Genres', 'Plot Keywords', 'Language', 'Country', 'Content Rating', 'Color',

    # roles information
    'Director', 'Actor Name 1', 'Actor Name 2', 'Actor Name 3',

    # Financials
    'Budget', 'Gross',

    # IMDB and Review Metrics
    'IMDB Score', 'Number of Voted Users', 'Number of User Reviews', 'Number of Critic Reviews',

    # Social Media Presence
    'Movie Facebook Likes', 'Director Facebook Likes', 'Actor 1 Facebook Likes',
    'Actor 2 Facebook Likes', 'Actor 3 Facebook Likes', 'Cast Total Facebook Likes',

    # Additional Information
    'Duration', 'Number of Faces in Poster', 'Aspect Ratio'
]

# Reordering the column in dataframe
df1 = df[new_column_arrangement]

# Display the first few rows from the dataset
df1.head()
# Out:
#                                          Movie Title  Title Year  \
# 0                                            Avatar       2009.0
# 1          Pirates of the Caribbean: At World's End       2007.0
# 2                                           Spectre       2015.0
# 3                             The Dark Knight Rises       2012.0
# 4  Star Wars: Episode VII - The Force Awakens    ...         NaN
#
#                                      Movie IMDB Link  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 3  http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# 4  http://www.imdb.com/title/tt5289954/?ref_=fn_t...
#
#                             Genres  \
# 0  Action|Adventure|Fantasy|Sci-Fi
# 1         Action|Adventure|Fantasy
# 2        Action|Adventure|Thriller
# 3                  Action|Thriller
# 4                      Documentary
#
#                                        Plot Keywords Language Country  \
# 0             avatar|future|marine|native|paraplegic  English     USA
# 1  goddess|marriage ceremony|marriage proposal|pi...  English     USA
# 2                bomb|espionage|sequel|spy|terrorist  English      UK
# 3  deception|imprisonment|lawlessness|police offi...  English     USA
# 4                                                NaN      NaN     NaN
#
#   Content Rating  Color           Director  ... Number of Critic Reviews  \
# 0          PG-13  Color      James Cameron  ...                    723.0
# 1          PG-13  Color     Gore Verbinski  ...                    302.0
# 2          PG-13  Color         Sam Mendes  ...                    602.0
# 3          PG-13  Color  Christopher Nolan  ...                    813.0
# 4            NaN    NaN        Doug Walker  ...                      NaN
#
#   Movie Facebook Likes Director Facebook Likes  Actor 1 Facebook Likes  \
# 0                33000                     0.0                  1000.0
# 1                    0                   563.0                 40000.0
# 2                85000                     0.0                 11000.0
# 3               164000                 22000.0                 27000.0
# 4                    0                   131.0                   131.0
#
#    Actor 2 Facebook Likes  Actor 3 Facebook Likes  Cast Total Facebook Likes  \
# 0                   936.0                   855.0                       4834
# 1                  5000.0                  1000.0                      48350
# 2                   393.0                   161.0                      11700
# 3                 23000.0                 23000.0                     106759
# 4                    12.0                     NaN                        143
#
#    Duration  Number of Faces in Poster  Aspect Ratio
# 0     178.0                        0.0          1.78
# 1     169.0                        0.0          2.35
# 2     148.0                        1.0          2.35
# 3     164.0                        0.0          2.35
# 4       NaN                        0.0           NaN
#
# [5 rows x 28 columns]

# %%
#Dropping Columns that doesn't needed further
dropped_columns=[ 'Movie IMDB Link','Plot Keywords','Color','Title Year',
                 'Language','Country','Content Rating', 'Duration','Aspect Ratio', 'Cast Total Facebook Likes' ,
                  'Number of Faces in Poster', 'Movie Facebook Likes',
                  'Director Facebook Likes','Actor 1 Facebook Likes','Actor 2 Facebook Likes','Actor 3 Facebook Likes',
                  'Number of User Reviews', 'Number of Voted Users','Number of Critic Reviews'
]
df1.drop(columns=dropped_columns, axis=1, inplace=True)
# Out:
# <ipython-input-47-eb067c7ef15c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns=dropped_columns, axis=1, inplace=True)

# %%
df1
# Out:
#                                             Movie Title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# 5040                              A Plague So Pleasant
# 5041                                  Shanghai Calling
# 5042                                 My Date with Drew
#
#                                Genres           Director     Actor Name 1  \
# 0     Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1            Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2           Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                     Action|Thriller  Christopher Nolan        Tom Hardy
# 4                         Documentary        Doug Walker      Doug Walker
# ...                               ...                ...              ...
# 5038                     Comedy|Drama        Scott Smith      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller                NaN      Natalie Zea
# 5040            Drama|Horror|Thriller   Benjamin Roberds      Eva Boehnke
# 5041             Comedy|Drama|Romance        Daniel Hsia        Alan Ruck
# 5042                      Documentary           Jon Gunn      John August
#
#           Actor Name 2          Actor Name 3       Budget        Gross  \
# 0     Joel David Moore             Wes Studi  237000000.0  760505847.0
# 1        Orlando Bloom        Jack Davenport  300000000.0  309404152.0
# 2         Rory Kinnear      Stephanie Sigman  245000000.0  200074175.0
# 3       Christian Bale  Joseph Gordon-Levitt  250000000.0  448130642.0
# 4           Rob Walker                   NaN          NaN          NaN
# ...                ...                   ...          ...          ...
# 5038     Daphne Zuniga          Crystal Lowe          NaN          NaN
# 5039     Valorie Curry         Sam Underwood          NaN          NaN
# 5040     Maxwell Moody        David Chandler       1400.0          NaN
# 5041     Daniel Henney           Eliza Coupe          NaN      10443.0
# 5042  Brian Herzlinger              Jon Gunn       1100.0      85222.0
#
#       IMDB Score
# 0            7.9
# 1            7.1
# 2            6.8
# 3            8.5
# 4            7.1
# ...          ...
# 5038         7.7
# 5039         7.5
# 5040         6.3
# 5041         6.3
# 5042         6.6
#
# [5043 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# Movie Title       0
# Genres            0
# Director        104
# Actor Name 1      7
# Actor Name 2     13
# Actor Name 3     23
# Budget          492
# Gross           884
# IMDB Score        0
# dtype: int64

# %%
row_count = len(df1)

print(row_count)
# Out:
# 5043

# %%
# Removing the null values from the dataset so that predictions are better
df1.dropna(axis=0,subset=['Gross','Director','Budget','Actor Name 1','Actor Name 2','Actor Name 3'],inplace=True)
# Out:
# <ipython-input-51-2d0c09a17cb6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(axis=0,subset=['Gross','Director','Budget','Actor Name 1','Actor Name 2','Actor Name 3'],inplace=True)

# %%
# Here we are removed all the null values

df1.isna().sum()
# Out:
# Movie Title     0
# Genres          0
# Director        0
# Actor Name 1    0
# Actor Name 2    0
# Actor Name 3    0
# Budget          0
# Gross           0
# IMDB Score      0
# dtype: int64

# %%
df1
# Out:
#                                     Movie Title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5033                                    Primer
# 5034                                    Cavite
# 5035                               El Mariachi
# 5037                                 Newlyweds
# 5042                         My Date with Drew
#
#                                    Genres           Director     Actor Name 1  \
# 0         Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1                Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2               Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                         Action|Thriller  Christopher Nolan        Tom Hardy
# 5                 Action|Adventure|Sci-Fi     Andrew Stanton     Daryl Sabara
# ...                                   ...                ...              ...
# 5033                Drama|Sci-Fi|Thriller      Shane Carruth    Shane Carruth
# 5034                             Thriller   Neill Dela Llana      Ian Gamazon
# 5035  Action|Crime|Drama|Romance|Thriller   Robert Rodriguez  Carlos Gallardo
# 5037                         Comedy|Drama       Edward Burns      Kerry Bishé
# 5042                          Documentary           Jon Gunn      John August
#
#             Actor Name 2          Actor Name 3       Budget        Gross  \
# 0       Joel David Moore             Wes Studi  237000000.0  760505847.0
# 1          Orlando Bloom        Jack Davenport  300000000.0  309404152.0
# 2           Rory Kinnear      Stephanie Sigman  245000000.0  200074175.0
# 3         Christian Bale  Joseph Gordon-Levitt  250000000.0  448130642.0
# 5        Samantha Morton          Polly Walker  263700000.0   73058679.0
# ...                  ...                   ...          ...          ...
# 5033      David Sullivan          Casey Gooden       7000.0     424760.0
# 5034     Edgar Tancangco             Quynn Ton       7000.0      70071.0
# 5035     Peter Marquardt        Consuelo Gómez       7000.0    2040920.0
# 5037  Caitlin FitzGerald       Daniella Pineda       9000.0       4584.0
# 5042    Brian Herzlinger              Jon Gunn       1100.0      85222.0
#
#       IMDB Score
# 0            7.9
# 1            7.1
# 2            6.8
# 3            8.5
# 5            6.6
# ...          ...
# 5033         7.0
# 5034         6.3
# 5035         6.9
# 5037         6.4
# 5042         6.6
#
# [3881 rows x 9 columns]

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
df1['Budget_in_million']=df1['Budget']/1000000
df1['Gross_in_million']=df1['Gross']/1000000

df1.drop(['Budget','Gross'],axis=1,inplace=True)
# Out:
# <ipython-input-54-c4743119072c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Budget_in_million']=df1['Budget']/1000000
# <ipython-input-54-c4743119072c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Gross_in_million']=df1['Gross']/1000000
# <ipython-input-54-c4743119072c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['Budget','Gross'],axis=1,inplace=True)

# %%
# Creating profit column

df1['Profit'] = df1['Gross_in_million'] - df1['Budget_in_million']
# Out:
# <ipython-input-55-776bb020188f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Profit'] = df1['Gross_in_million'] - df1['Budget_in_million']

# %%
df1
# Out:
#                                     Movie Title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5033                                    Primer
# 5034                                    Cavite
# 5035                               El Mariachi
# 5037                                 Newlyweds
# 5042                         My Date with Drew
#
#                                    Genres           Director     Actor Name 1  \
# 0         Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1                Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2               Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                         Action|Thriller  Christopher Nolan        Tom Hardy
# 5                 Action|Adventure|Sci-Fi     Andrew Stanton     Daryl Sabara
# ...                                   ...                ...              ...
# 5033                Drama|Sci-Fi|Thriller      Shane Carruth    Shane Carruth
# 5034                             Thriller   Neill Dela Llana      Ian Gamazon
# 5035  Action|Crime|Drama|Romance|Thriller   Robert Rodriguez  Carlos Gallardo
# 5037                         Comedy|Drama       Edward Burns      Kerry Bishé
# 5042                          Documentary           Jon Gunn      John August
#
#             Actor Name 2          Actor Name 3  IMDB Score  Budget_in_million  \
# 0       Joel David Moore             Wes Studi         7.9           237.0000
# 1          Orlando Bloom        Jack Davenport         7.1           300.0000
# 2           Rory Kinnear      Stephanie Sigman         6.8           245.0000
# 3         Christian Bale  Joseph Gordon-Levitt         8.5           250.0000
# 5        Samantha Morton          Polly Walker         6.6           263.7000
# ...                  ...                   ...         ...                ...
# 5033      David Sullivan          Casey Gooden         7.0             0.0070
# 5034     Edgar Tancangco             Quynn Ton         6.3             0.0070
# 5035     Peter Marquardt        Consuelo Gómez         6.9             0.0070
# 5037  Caitlin FitzGerald       Daniella Pineda         6.4             0.0090
# 5042    Brian Herzlinger              Jon Gunn         6.6             0.0011
#
#       Gross_in_million      Profit
# 0           760.505847  523.505847
# 1           309.404152    9.404152
# 2           200.074175  -44.925825
# 3           448.130642  198.130642
# 5            73.058679 -190.641321
# ...                ...         ...
# 5033          0.424760    0.417760
# 5034          0.070071    0.063071
# 5035          2.040920    2.033920
# 5037          0.004584   -0.004416
# 5042          0.085222    0.084122
#
# [3881 rows x 10 columns]

# %%
# Checking how many duplicated values are there in the dataset

df1[df1.duplicated()].value_counts()
# Out:
# Movie Title                Genres                                            Director        Actor Name 1       Actor Name 2         Actor Name 3       IMDB Score  Budget_in_million  Gross_in_million  Profit
# King Kong                  Action|Adventure|Drama|Romance                    Peter Jackson   Naomi Watts        Thomas Kretschmann   Evan Parke         7.2         207.0              218.051260         11.051260     2
# Pan                        Adventure|Family|Fantasy                          Joe Wright      Hugh Jackman       Cara Delevingne      Nonso Anozie       5.8         150.0              34.964818         -115.035182    2
# Halloween                  Horror|Thriller                                   John Carpenter  Jamie Lee Curtis   Donald Pleasence     P.J. Soles         7.9         0.3                47.000000          46.700000     2
# Home                       Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi  Tim Johnson     Jim Parsons        Matt Jones           April Winchell     6.7         135.0              177.343675         42.343675     2
# The Fast and the Furious   Action|Crime|Thriller                             Rob Cohen       Paul Walker        Vin Diesel           Jordana Brewster   6.7         38.0               144.512310         106.512310    2
#                                                                                                                                                                                                                        ..
# Goosebumps                 Adventure|Comedy|Family|Fantasy|Horror            Rob Letterman   Odeya Rush         Dylan Minnette       Ken Marino         6.4         58.0               80.021740          22.021740     1
# Glory                      Drama|History|War                                 Edward Zwick    Denzel Washington  Morgan Freeman       Matthew Broderick  7.9         18.0               26.830000          8.830000      1
# Ghostbusters               Action|Comedy|Fantasy|Sci-Fi                      Paul Feig       Ed Begley Jr.      Kate McKinnon        Zach Woods         5.5         144.0              118.099659        -25.900341     1
# From Hell                  Horror|Mystery|Thriller                           Albert Hughes   Johnny Depp        Jason Flemyng        Ian Richardson     6.8         35.0               31.598308         -3.401692      1
# Wicker Park                Drama|Mystery|Romance|Thriller                    Paul McGuigan   Jessica Paré       Christopher Cousins  Mark Camacho       7.0         30.0               12.831121         -17.168879     1
# Name: count, Length: 94, dtype: int64

# %%
# Dropping those duplicate values

df1=df1.drop_duplicates()

# %%
final_count = len(df1)

# %%
# Calculate data loss in terms of row count and percentage
rows_lost = row_count - final_count
percentage_lost = (rows_lost / row_count) * 100

# Display the results
print(f"Initial Row Count: {row_count}")
print(f"Final Row Count: {final_count}")
print(f"Rows Lost: {rows_lost}")
print(f"Percentage of Data Lost: {percentage_lost:.2f}%")
# Out:
# Initial Row Count: 5043
# Final Row Count: 3781
# Rows Lost: 1262
# Percentage of Data Lost: 25.02%

# %%
df1
# Out:
#                                     Movie Title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5033                                    Primer
# 5034                                    Cavite
# 5035                               El Mariachi
# 5037                                 Newlyweds
# 5042                         My Date with Drew
#
#                                    Genres           Director     Actor Name 1  \
# 0         Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1                Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2               Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                         Action|Thriller  Christopher Nolan        Tom Hardy
# 5                 Action|Adventure|Sci-Fi     Andrew Stanton     Daryl Sabara
# ...                                   ...                ...              ...
# 5033                Drama|Sci-Fi|Thriller      Shane Carruth    Shane Carruth
# 5034                             Thriller   Neill Dela Llana      Ian Gamazon
# 5035  Action|Crime|Drama|Romance|Thriller   Robert Rodriguez  Carlos Gallardo
# 5037                         Comedy|Drama       Edward Burns      Kerry Bishé
# 5042                          Documentary           Jon Gunn      John August
#
#             Actor Name 2          Actor Name 3  IMDB Score  Budget_in_million  \
# 0       Joel David Moore             Wes Studi         7.9           237.0000
# 1          Orlando Bloom        Jack Davenport         7.1           300.0000
# 2           Rory Kinnear      Stephanie Sigman         6.8           245.0000
# 3         Christian Bale  Joseph Gordon-Levitt         8.5           250.0000
# 5        Samantha Morton          Polly Walker         6.6           263.7000
# ...                  ...                   ...         ...                ...
# 5033      David Sullivan          Casey Gooden         7.0             0.0070
# 5034     Edgar Tancangco             Quynn Ton         6.3             0.0070
# 5035     Peter Marquardt        Consuelo Gómez         6.9             0.0070
# 5037  Caitlin FitzGerald       Daniella Pineda         6.4             0.0090
# 5042    Brian Herzlinger              Jon Gunn         6.6             0.0011
#
#       Gross_in_million      Profit
# 0           760.505847  523.505847
# 1           309.404152    9.404152
# 2           200.074175  -44.925825
# 3           448.130642  198.130642
# 5            73.058679 -190.641321
# ...                ...         ...
# 5033          0.424760    0.417760
# 5034          0.070071    0.063071
# 5035          2.040920    2.033920
# 5037          0.004584   -0.004416
# 5042          0.085222    0.084122
#
# [3781 rows x 10 columns]

# %%
# Filtering data from genre column to get only "Romance" and "Horror" values
filtered_df = df1[df1['Genres'].str.contains("Romance|Horror", case=False, na=False)]

# Create a new 'Main_Genre' column to classify movies into 'Romance' or 'Horror'
filtered_df['Main_Genre'] = filtered_df['Genres'].apply(lambda x: 'Romance' if 'Romance' in x else 'Horror')

# Count plot for the number of movies in each genre
plt.figure(figsize=(10, 8))
sns.countplot(x='Main_Genre', data=filtered_df,hue='Main_Genre',legend=False,palette={"Romance": "cyan", "Horror": "darkblue"})

# Title and labels
plt.title("Count of Movies by Genre: Romance vs. Horror")
plt.xlabel("Genre")
plt.ylabel("Count of Movies")

# Show plot
plt.show()
# Out:
# <ipython-input-62-7178c7e15d8b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Main_Genre'] = filtered_df['Genres'].apply(lambda x: 'Romance' if 'Romance' in x else 'Horror')

# %%
filtered_df
# Out:
#             Movie Title                                             Genres  \
# 6         Spider-Man 3                            Action|Adventure|Romance
# 7              Tangled   Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 25           King Kong                      Action|Adventure|Drama|Romance
# 26             Titanic                                       Drama|Romance
# 31        Spider-Man 2                    Action|Adventure|Fantasy|Romance
# ...                 ...                                                ...
# 5023  Breaking Upwards                                             Romance
# 5025    Pink Flamingos                                 Comedy|Crime|Horror
# 5026             Clean                                 Drama|Music|Romance
# 5029          The Cure                       Crime|Horror|Mystery|Thriller
# 5035       El Mariachi                 Action|Crime|Drama|Romance|Thriller
#
#               Director       Actor Name 1        Actor Name 2  \
# 6            Sam Raimi       J.K. Simmons        James Franco
# 7         Nathan Greno       Brad Garrett        Donna Murphy
# 25       Peter Jackson        Naomi Watts  Thomas Kretschmann
# 26       James Cameron  Leonardo DiCaprio        Kate Winslet
# 31           Sam Raimi       J.K. Simmons        James Franco
# ...                ...                ...                 ...
# 5023        Daryl Wein   Zoe Lister-Jones       Heather Burns
# 5025       John Waters             Divine          Mink Stole
# 5026   Olivier Assayas      Maggie Cheung      Béatrice Dalle
# 5029  Kiyoshi Kurosawa       Kôji Yakusho       Anna Nakagawa
# 5035  Robert Rodriguez    Carlos Gallardo     Peter Marquardt
#
#             Actor Name 3  IMDB Score  Budget_in_million  Gross_in_million  \
# 6          Kirsten Dunst         6.2           258.0000        336.530303
# 7            M.C. Gainey         7.8           260.0000        200.807262
# 25            Evan Parke         7.2           207.0000        218.051260
# 26         Gloria Stuart         7.7           200.0000        658.672302
# 31         Kirsten Dunst         7.3           200.0000        373.377893
# ...                  ...         ...                ...               ...
# 5023  Ebon Moss-Bachrach         6.2             0.0150          0.076382
# 5025        Edith Massey         6.1             0.0100          0.180483
# 5026        Don McKellar         6.9             0.0045          0.136007
# 5029              Denden         7.4             1.0000          0.094596
# 5035      Consuelo Gómez         6.9             0.0070          2.040920
#
#           Profit Main_Genre
# 6      78.530303    Romance
# 7     -59.192738    Romance
# 25     11.051260    Romance
# 26    458.672302    Romance
# 31    173.377893    Romance
# ...          ...        ...
# 5023    0.061382    Romance
# 5025    0.170483     Horror
# 5026    0.131507    Romance
# 5029   -0.905404     Horror
# 5035    2.033920    Romance
#
# [1236 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter dataset for Romance and Horror movies
romance_movies = df1[df1['Genres'].str.contains("Romance", case=False, na=False)]
horror_movies = df1[df1['Genres'].str.contains("Horror", case=False, na=False)]

# Plot IMDb Score distributions
plt.figure(figsize=(12, 8))
sns.histplot(romance_movies['IMDB Score'], bins=15, color='magenta', kde=True, label='Romance')
sns.histplot(horror_movies['IMDB Score'], bins=15, color='darkred', kde=True, label='Horror')
plt.title("IMDb Score Distribution: Romance vs. Horror Movies")
plt.xlabel("IMDb Score")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
# Boxplot for Budget comparison with hue specified
plt.figure(figsize=(12, 8))
sns.boxplot(x='Main_Genre', y='Budget_in_million', hue='Main_Genre', data=filtered_df,
            palette={"Romance": "salmon", "Horror": "darkred"}, dodge=False)
plt.title("Budget Comparison: Romance vs. Horror Movies")
plt.ylabel("Budget (in million $)")
plt.xlabel("Genre")
plt.legend(title="Genre")
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Boxplot for Gross comparison with hue specified
plt.figure(figsize=(12, 6))
sns.boxplot(x='Main_Genre', y='Gross_in_million', hue='Main_Genre', data=filtered_df,
            palette={"Romance": "salmon", "Horror": "darkred"}, dodge=False)
plt.title("Gross Revenue Comparison: Romance vs. Horror Movies")
plt.ylabel("Gross Revenue (in million $)")
plt.xlabel("Genre")
plt.legend(title="Genre")
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot boxplot for Profit
plt.figure(figsize=(12, 6))
sns.boxplot(x='Main_Genre', y='Profit', data=filtered_df,hue='Main_Genre',legend=False, palette={"Romance": "salmon", "Horror": "darkred"})

# Title and labels
plt.title("Profit Comparison: Romance vs. Horror Movies")
plt.ylabel("Profit (in million $)")

# Show plot
plt.show()

# %%
# Plot boxplot for IMDB Score
plt.figure(figsize=(10, 6))
sns.boxplot(x='Main_Genre', y='IMDB Score', data=filtered_df,hue='Main_Genre',legend=False,palette={"Romance": "yellow", "Horror": "darkred"})

# Title and labels
plt.title("IMDB Score Count: Romance vs. Horror Movies")
plt.ylabel("Count of IMDB Score")

# Show plot
plt.show()

# %%
# Scatter plot of IMDB Score vs. Profit by Genre
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df1, x='IMDB Score', y='Profit', hue=df['Genres'].apply(lambda x: 'Romance' if 'Romance' in x else 'Horror'))
plt.title('IMDB Score vs Profit by Genre')
plt.xlabel('IMDB Score')
plt.ylabel('Profit')
plt.legend(title='Genre')
plt.show()

# %%
# Function to remove outliers using IQR method
def remove_outliers(df1, column):
    Quar1 = df1[column].quantile(0.25)
    Quar3 = df1[column].quantile(0.75)
    IQR = Quar3 - Quar1
    lower_bound = Quar1 - 1.5 * IQR
    upper_bound = Quar3 + 1.5 * IQR
    return df1[(df1[column] >= lower_bound) & (df1[column] <= upper_bound)]

# Apply outlier removal on Budget, Gross, and Profit columns
df1 = remove_outliers(df1, 'Budget_in_million')
df1 = remove_outliers(df1, 'Gross_in_million')
df1 = remove_outliers(df1, 'Profit')
df1= remove_outliers(df1, 'IMDB Score')

# %%
final_count = len(df1)

# %%
rows_lost = row_count - final_count
percentage_lost = (rows_lost / row_count) * 100

# Display the results
print(f"Initial Row Count: {row_count}")
print(f"Final Row Count: {final_count}")
print(f"Rows Lost due to outlier removal: {rows_lost}")
print(f"Percentage of Data Lost: {percentage_lost:.2f}%")
# Out:
# Initial Row Count: 5043
# Final Row Count: 3036
# Rows Lost due to outlier removal: 2007
# Percentage of Data Lost: 39.80%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Pairplot to include Budget, Gross, Profit, and IMDB Score for both genres
sns.pairplot(filtered_df,
             vars=['Budget_in_million', 'Gross_in_million', 'Profit', 'IMDB Score'],
             hue='Main_Genre',
             palette={"Romance": "salmon", "Horror": "darkred"},
             plot_kws={'alpha': 0.6})
plt.suptitle("Pairplot of Budget, Gross, Profit, and IMDB Score (After Outlier Removal)", y=1.02)
plt.show()

# %%
# 2. Jointplot for Profit vs IMDB Score for Horror movies
sns.jointplot(data=filtered_df[filtered_df['Main_Genre'] == 'Horror'],
              x='Profit', y='IMDB Score',
              kind='scatter', color="darkorange", alpha=0.6,
              marginal_kws=dict(bins=20, fill=True))
plt.suptitle("Jointplot of Profit vs IMDB Score for Horror (After Outlier Removal)", y=1.02)
plt.show()

# %%
# 3. Jointplot for Profit vs IMDB Score for Romance movies
sns.jointplot(data=filtered_df[filtered_df['Main_Genre'] == 'Romance'],
              x='Profit', y='IMDB Score',
              kind='scatter', color="blue", alpha=0.7,
              marginal_kws=dict(bins=30, fill=True))
plt.suptitle("Jointplot of Profit vs IMDB Score for Romance (After Outlier Removal)", y=1.02)
plt.show()

# %%
romance_data = filtered_df[filtered_df['Main_Genre'] == 'Romance']
romance_data
# Out:
#                        Movie Title  \
# 6                    Spider-Man 3
# 7                         Tangled
# 25                      King Kong
# 26                        Titanic
# 31                   Spider-Man 2
# ...                            ...
# 4998  Smiling Fish & Goat on Fire
# 5021              The Puffy Chair
# 5023             Breaking Upwards
# 5026                        Clean
# 5035                  El Mariachi
#
#                                                  Genres          Director  \
# 6                              Action|Adventure|Romance         Sam Raimi
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...      Nathan Greno
# 25                       Action|Adventure|Drama|Romance     Peter Jackson
# 26                                        Drama|Romance     James Cameron
# 31                     Action|Adventure|Fantasy|Romance         Sam Raimi
# ...                                                 ...               ...
# 4998                                     Comedy|Romance      Kevin Jordan
# 5021                               Comedy|Drama|Romance       Jay Duplass
# 5023                                            Romance        Daryl Wein
# 5026                                Drama|Music|Romance   Olivier Assayas
# 5035                Action|Crime|Drama|Romance|Thriller  Robert Rodriguez
#
#            Actor Name 1        Actor Name 2        Actor Name 3  IMDB Score  \
# 6          J.K. Simmons        James Franco       Kirsten Dunst         6.2
# 7          Brad Garrett        Donna Murphy         M.C. Gainey         7.8
# 25          Naomi Watts  Thomas Kretschmann          Evan Parke         7.2
# 26    Leonardo DiCaprio        Kate Winslet       Gloria Stuart         7.7
# 31         J.K. Simmons        James Franco       Kirsten Dunst         7.3
# ...                 ...                 ...                 ...         ...
# 4998     Derick Martini      Christa Miller         Ion Overman         7.6
# 5021       Mark Duplass       Katie Aselton          Bari Hyman         6.6
# 5023   Zoe Lister-Jones       Heather Burns  Ebon Moss-Bachrach         6.2
# 5026      Maggie Cheung      Béatrice Dalle        Don McKellar         6.9
# 5035    Carlos Gallardo     Peter Marquardt      Consuelo Gómez         6.9
#
#       Budget_in_million  Gross_in_million      Profit Main_Genre
# 6              258.0000        336.530303   78.530303    Romance
# 7              260.0000        200.807262  -59.192738    Romance
# 25             207.0000        218.051260   11.051260    Romance
# 26             200.0000        658.672302  458.672302    Romance
# 31             200.0000        373.377893  173.377893    Romance
# ...                 ...               ...         ...        ...
# 4998             0.0400          0.277233    0.237233    Romance
# 5021             0.0150          0.192467    0.177467    Romance
# 5023             0.0150          0.076382    0.061382    Romance
# 5026             0.0045          0.136007    0.131507    Romance
# 5035             0.0070          2.040920    2.033920    Romance
#
# [868 rows x 11 columns]

# %%
horror_data = filtered_df[filtered_df['Main_Genre'] == 'Horror']
horror_data
# Out:
#                                  Movie Title  \
# 46                              World War Z
# 72    The Mummy: Tomb of the Dragon Emperor
# 117                             I Am Legend
# 134                            Dark Shadows
# 136                             The Wolfman
# ...                                      ...
# 4956                            The Gallows
# 4962           The Lost Skeleton of Cadavra
# 4964                          Cheap Thrills
# 5025                         Pink Flamingos
# 5029                               The Cure
#
#                                         Genres          Director  \
# 46     Action|Adventure|Horror|Sci-Fi|Thriller      Marc Forster
# 72    Action|Adventure|Fantasy|Horror|Thriller         Rob Cohen
# 117                        Drama|Horror|Sci-Fi  Francis Lawrence
# 134                      Comedy|Fantasy|Horror        Tim Burton
# 136              Drama|Fantasy|Horror|Thriller      Joe Johnston
# ...                                        ...               ...
# 4956                           Horror|Thriller      Travis Cluff
# 4962                      Comedy|Horror|Sci-Fi     Larry Blamire
# 4964        Comedy|Crime|Drama|Horror|Thriller         E.L. Katz
# 5025                       Comedy|Crime|Horror       John Waters
# 5029             Crime|Horror|Mystery|Thriller  Kiyoshi Kurosawa
#
#            Actor Name 1        Actor Name 2     Actor Name 3  IMDB Score  \
# 46        Peter Capaldi           Brad Pitt    Mireille Enos         7.0
# 72               Jet Li      Brendan Fraser     Russell Wong         5.2
# 117          Will Smith         Alice Braga     Willow Smith         7.2
# 134         Johnny Depp  Chloë Grace Moretz  Christopher Lee         6.2
# 136     Anthony Hopkins      Simon Merrells        Art Malik         5.8
# ...                 ...                 ...              ...         ...
# 4956      Pfeifer Brown     Cassidy Gifford    Reese Mishler         4.2
# 4962      Fay Masterson          Brian Howe    Larry Blamire         7.0
# 4964  Brighton Sharbino         Ethan Embry   Elissa Dowling         6.8
# 5025             Divine          Mink Stole     Edith Massey         6.1
# 5029       Kôji Yakusho       Anna Nakagawa           Denden         7.4
#
#       Budget_in_million  Gross_in_million      Profit Main_Genre
# 46               190.00        202.351611   12.351611     Horror
# 72               145.00        102.176165  -42.823835     Horror
# 117              150.00        256.386216  106.386216     Horror
# 134              100.00         79.711678  -20.288322     Horror
# 136              150.00         61.937495  -88.062505     Horror
# ...                 ...               ...         ...        ...
# 4956               0.10         22.757819   22.657819     Horror
# 4962               0.04          0.110536    0.070536     Horror
# 4964               0.20          0.059379   -0.140621     Horror
# 5025               0.01          0.180483    0.170483     Horror
# 5029               1.00          0.094596   -0.905404     Horror
#
# [368 rows x 11 columns]

# %%
import scipy.stats as stats

# Separate the data into two groups based on Genre_Category
romance_data = filtered_df[filtered_df['Main_Genre'] == 'Romance']
horror_data = filtered_df[filtered_df['Main_Genre'] == 'Horror']

# 1. Hypothesis Test for Profit Differences (Two-Sample T-Test)

# Null Hypothesis (H0): The mean profit of Romance movies is equal to the mean profit of Horror movies.
# Alternative Hypothesis (H1): The mean profit of Romance movies is different from the mean profit of Horror movies.

# Perform the independent two-sample t-test on 'Profit'
t_statistic_profit, p_value_profit = stats.ttest_ind(romance_data['Profit'], horror_data['Profit'], equal_var=False)

print("Hypothesis Test for Profit Differences")
print("T-statistic:", t_statistic_profit)
print("P-value:", p_value_profit)
if p_value_profit < 0.05:
    print("Reject the null hypothesis: Significant difference in profit between Romance and Horror movies.")
else:
    print("Fail to reject the null hypothesis: No significant difference in profit between Romance and Horror movies.")

# 2. Hypothesis Test for IMDB Score Differences (Two-Sample T-Test)

# Null Hypothesis (H0): The mean IMDB score of Romance movies is equal to the mean IMDB score of Horror movies.
# Alternative Hypothesis (H1): The mean IMDB score of Romance movies is different from the mean IMDB score of Horror movies.

# Perform the independent two-sample t-test on 'IMDB Score'
t_statistic_imdb, p_value_imdb = stats.ttest_ind(romance_data['IMDB Score'], horror_data['IMDB Score'], equal_var=False)

print("\nHypothesis Test for IMDB Score Differences")
print("T-statistic:", t_statistic_imdb)
print("P-value:", p_value_imdb)
if p_value_imdb < 0.05:
    print("Reject the null hypothesis: Significant difference in IMDB scores between Romance and Horror movies.")
else:
    print("Fail to reject the null hypothesis: No significant difference in IMDB scores between Romance and Horror movies.")
# Out:
# Hypothesis Test for Profit Differences
# T-statistic: 0.8770940924259678
# P-value: 0.380997547857572
# Fail to reject the null hypothesis: No significant difference in profit between Romance and Horror movies.
#
# Hypothesis Test for IMDB Score Differences
# T-statistic: 8.42400324341145
# P-value: 2.1877915592737557e-16
# Reject the null hypothesis: Significant difference in IMDB scores between Romance and Horror movies.

# %%
romance_data.describe().loc[['mean', 'std', '50%','75%', 'max']][['IMDB Score', 'Profit']]
# Out:
#       IMDB Score      Profit
# mean    6.423963    9.480335
# std     0.969156  100.119458
# 50%     6.500000    1.481404
# 75%     7.100000   24.295217
# max     8.500000  458.672302

# %%
horror_data.describe().loc[['mean', 'std', '50%','75%', 'max']][['IMDB Score', 'Profit']]
# Out:
#       IMDB Score      Profit
# mean    5.906250  -19.845236
# std     0.995844  638.071456
# 50%     5.950000    6.601891
# 75%     6.600000   23.875779
# max     8.600000  196.565000

# %%
# Calculate and display mean values for each metric by genre
mean_profit_romance = romance_data['Profit'].mean()
mean_profit_horror = horror_data['Profit'].mean()
mean_imdb_romance = romance_data['IMDB Score'].mean()
mean_imdb_horror = horror_data['IMDB Score'].mean()


print("\nMean Metrics by Genre")
print("Mean Profit - Romance:", mean_profit_romance)
print("Mean Profit - Horror:", mean_profit_horror)
print("Mean IMDB Score - Romance:", mean_imdb_romance)
print("Mean IMDB Score - Horror:", mean_imdb_horror)
# Out:
# Mean Metrics by Genre
# Mean Profit - Romance: 9.480334649769585
# Mean Profit - Horror: -19.84523629891304
# Mean IMDB Score - Romance: 6.423963133640553
# Mean IMDB Score - Horror: 5.90625

# %% [markdown]
#  **From the above observation we can see that Profit and IMDB Score for Romance Genre is higher than Horror Genre.**
#
# **And hence we can conclude that producing Romance Genre movie can be much more profitable as compared to horror genre.**

# %%
# Top 10 Directors based on Profit and IMDB Score
# Group by Director and aggregate the Profit and IMDB Score
top_directors = df1.groupby('Director').agg(
    Average_Profit=('Profit', 'mean'),
    Average_IMDB_Score=('IMDB Score', 'mean')
).sort_values(by='Average_Profit', ascending=False).head(10)

# Display top directors
print("Top 10 Directors based on Profit and IMDB Score:")
print(top_directors)


# Top 10 Actors based on Profit and IMDB Score
# Consolidate the actor columns to aggregate performance across all actors
actors = pd.concat([
    df1[['Actor Name 1', 'Profit', 'IMDB Score']].rename(columns={'Actor Name 1': 'Actor'}),
    df1[['Actor Name 2', 'Profit', 'IMDB Score']].rename(columns={'Actor Name 2': 'Actor'}),
    df1[['Actor Name 3', 'Profit', 'IMDB Score']].rename(columns={'Actor Name 3': 'Actor'})
])

# Group by Actor and aggregate Profit and IMDB Score
top_actors = actors.groupby('Actor').agg(
    Average_Profit=('Profit', 'mean'),
    Average_IMDB_Score=('IMDB Score', 'mean')
).sort_values(by='Average_Profit', ascending=False).head(10)

# Display top actors
print("\nTop 10 Actors based on Profit and IMDB Score:")
print(top_actors)
# Out:
# Top 10 Directors based on Profit and IMDB Score:
#                     Average_Profit  Average_IMDB_Score
# Director
# Mike McCoy               58.011073                6.50
# Dan Trachtenberg         56.897215                7.30
# Stephen Hillenburg       55.416609                7.00
# Jim Gillespie            55.219395                5.60
# Ben Affleck              55.173235                7.60
# George Cukor             55.000000                7.90
# Michael Pressman         53.656813                6.00
# Peter Weir               53.500000                7.40
# Josh Trank               52.572496                7.10
# Nora Ephron              52.428484                6.75
#
# Top 10 Actors based on Profit and IMDB Score:
#                      Average_Profit  Average_IMDB_Score
# Actor
# Chris Lowell              58.813460                 7.4
# Clare Kramer              58.353550                 5.9
# Glenn Shadix              58.326666                 7.5
# Darcy Donavan             58.136909                 7.2
# Jason Cottle              58.011073                 6.5
# Rorke Denver              58.011073                 6.5
# Alex Veadov               58.011073                 6.5
# Brad Garrett              57.006880                 5.5
# Marcella Lentz-Pope       56.917897                 7.7
# Dustin Fitzsimons         56.917897                 7.7

# %%
# Top 10 movies based on IMDB Score
top_movies =df1.groupby('Movie Title').max('IMDB Score').sort_values(by='IMDB Score', ascending=False).head(10)
print("Top 10 Movies based on IMDB Score:")
print(top_movies)
# Out:
# Top 10 Movies based on IMDB Score:
#                                  IMDB Score  Budget_in_million  \
# Movie Title
# The Godfather: Part II                  9.0               13.0
# The Good, the Bad and the Ugly          8.9                1.2
# Fight Club                              8.8               63.0
# Goodfellas                              8.7               25.0
# Seven Samurai                           8.7                2.0
# City of God                             8.7                3.3
# Modern Times                            8.6                1.5
# American History X                      8.6                7.5
# Spirited Away                           8.6               19.0
# The Usual Suspects                      8.6                6.0
#
#                                  Gross_in_million     Profit
# Movie Title
# The Godfather: Part II                  57.300000  44.300000
# The Good, the Bad and the Ugly           6.100000   4.900000
# Fight Club                              37.023395 -25.976605
# Goodfellas                              46.836394  21.836394
# Seven Samurai                            0.269061  -1.730939
# City of God                              7.563397   4.263397
# Modern Times                             0.163245  -1.336755
# American History X                       6.712241  -0.787759
# Spirited Away                           10.049886  -8.950114
# The Usual Suspects                      23.272306  17.272306

# %%
print("Top Director based on Profit and IMDB Score:")
print(top_directors.index[0])
# Out:
# Top Director based on Profit and IMDB Score:
# Mike McCoy

# %%
print("Top Actor based on Profit and IMDB Score:")
print(top_actors.index[0])
# Out:
# Top Actor based on Profit and IMDB Score:
# Chris Lowell

# %%
# Code to display top 5 genre based on IMDB Score

df1['Genres_split'] = df1['Genres'].str.split('|')

df_exploded = df1.explode('Genres_split')


genre_counts = df_exploded['Genres_split'].value_counts()


top_5_genres = genre_counts.head(5)


top_5_genres_data = df_exploded[df_exploded['Genres_split'].isin(top_5_genres.index)]

# Step 6: Plot the IMDB score distribution for the top 5 genres
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genres_split', y='IMDB Score', data=top_5_genres_data, palette="Set2")
plt.title("IMDB Score Distribution for Top 5 Genres")
plt.xlabel("Genre")
plt.ylabel("IMDB Score")
plt.xticks(rotation=45)
plt.show()

# Step 7: Display summary statistics for IMDB Score for these top 5 genres
summary_stats = top_5_genres_data.groupby('Genres_split')['IMDB Score'].describe()

# Display summary statistics
print("Summary Statistics for IMDB Scores by Genre:")
print(summary_stats)
# Out:
# <ipython-input-89-548f21a1acef>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Genres_split', y='IMDB Score', data=top_5_genres_data, palette="Set2")
# Summary Statistics for IMDB Scores by Genre:
#                count      mean       std  min  25%  50%  75%  max
# Genres_split
# Action         622.0  6.183119  0.874429  3.9  5.6  6.2  6.7  8.7
# Comedy        1192.0  6.204950  0.889561  3.9  5.6  6.3  6.8  8.6
# Drama         1683.0  6.757635  0.829333  3.9  6.3  6.8  7.3  9.0
# Romance        737.0  6.455224  0.854323  3.9  5.9  6.5  7.1  8.4
# Thriller       925.0  6.346378  0.889221  3.9  5.8  6.4  6.9  8.6
